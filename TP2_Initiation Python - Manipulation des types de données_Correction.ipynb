# %% [markdown]
# <h2 style="text-align: center; background-color: #4d648d; font-family:Arial; color: white; padding: 13px; line-height: 1; border-radius:10px">Initiation Python - Manipulation des types de données 💻</h2>

# %% [markdown]
# **Résumé** Présentation de pyhton, exécution de commandes interactives ou de scripts avec un IDE, utilisation d'un calepin; les types et structures élémentaires de données, les structures de contrôle, les fonctions, classes et modules.

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# Entrer les commandes ci-dessous dans le calepin et les exécuter cellule par cellule en cliquant sur le bouton d'exécution de la cellule courante.

# %%
# Ceci est le début d'une session Python gérée à l'aide d'un notebook.
# Le script est divisé en cellules avec généralement l'affichage d'au plus un résultat par cellule.
## Importer les librairies nécessaires
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pylab import *
import os
## Définir si nécessaire le répertoire courant spécifique
##  à l'utilisateur
os.chdir(r'.')
## Commande magique pour obtenir les graphiques dans le calepin
# %matplotlib inline

# %%
# la déclaration de variables est simple sans initialisation
a=10
print(a)
b=2
print(a)
c,d=3,4
print(c)
print(d)
# Out:
# 10
# 10
# 3
# 4

# %%
a
# Out:
# 10

# %%
#%% Créer un data frame avec pandas
data = pd.DataFrame({
    'Gender': ['f', 'f', 'm', 'f', 'm', 'm', 'f', 'm', 'f', 'm'],
    'TV': [3.4, 3.5, 2.6, 4.7, 4.1, 4.0, 5.1, 4.0, 3.7, 2.1]})
data
# Out:
#   Gender   TV
# 0      f  3.4
# 1      f  3.5
# 2      m  2.6
# 3      f  4.7
# 4      m  4.1
# 5      m  4.0
# 6      f  5.1
# 7      m  4.0
# 8      f  3.7
# 9      m  2.1

# %%
print(data)
# Out:
#   Gender   TV
# 0      f  3.4
# 1      f  3.5
# 2      m  2.6
# 3      f  4.7
# 4      m  4.1
# 5      m  4.0
# 6      f  5.1
# 7      m  4.0
# 8      f  3.7
# 9      m  2.1

# %% [markdown]
# ## 2. Types de données

# %% [markdown]
# ### 2.1 Scalaires et chaînes
# La déclaration des variables est implicite ({integer, float, boolean, string), la syntaxe est très proche de celle du langage R mais il n'y a pas de type `factor`.

# %%
a=3  # est un entier
b=1. # est un flottant
# Attention:
a/2  # a pour résultat 1.5 en Python 3.4
     # mais 1 en 2.7
# Out:
# 1.5

# %%
#Les opérations standards
c=a+b
print(c)
c=a-b
print(c)
d=a*b
print(d)
e=a/b
print(e)
# Out:
# 4.0
# 2.0
# 3.0
# 3.0

# %% [markdown]
# Opérateurs de comparaison : `==, >, <, !=` de résultat booléen.

# %%
# Comparaison
a==b
# Out:
# False

# %%
#  affichage et type des variables
type(a)
# Out:
# int

# %%
# Chaîne de caractère
a='bonjour'
b='le '
c='monde'
a+b+c
# Out:
# 'bonjour le monde'

# %% [markdown]
# Attention à l'encodage des caractères. Ce n'est pas le même en python 2 (ascii) et python 3 (utf-8). Ce n'est pas fait dans ces exemples élémentaires mais il est vivement recommandé de gérer systématiquement des textes complexes avec caractères spéciaux (accents, guillements...) en utf-8

# %%
a=u'bonjour' # encodage utf-8
type(a)
# Out:
# str

# %%
a='bonjour'  # encodage ascii
type(a)
# Out:
# str

# %% [markdown]
# ### 2.2 Affichage de base

# %%
# affichage avec print
euro=1
print(euro)
print('euro : ',euro)
print('euro1 :',euro,'et', 'euro2',2*euro)
print('\n')
print('')
chaine='Bonjour' + ' Mr ' + 'Toto'
print(chaine)
print('')
# Out:
# 1
# euro :  1
# euro1 : 1 et euro2 2
#
#
#
# Bonjour Mr Toto

# %% [markdown]
# ### 2.3 Structures de base

# %% [markdown]
# #### Listes
# Les listes permettent des combinaisons de types.
# **Attention**, le premier élément d'une liste ou d'un tableau est indicé par **0**, pas par 1.

# %%
# exemples de listes
liste_A = [0,3,2,'hi']
liste_B = [0,3,2,4,5,6,1]
liste_C = [0,3,2,'hi',[1,2,3]]
# Elément d'une liste
liste_A[0]
# Out:
# 0

# %%
liste_A
# Out:
# [0, 3, 2, 'hi']

# %%
liste_C[-1] #  dernier élément
# Out:
# [1, 2, 3]

# %%
liste_C[-1][0]
# Out:
# 1

# %%
liste_C[-2]
# Out:
# 'hi'

# %%
liste_B[0:2] #  Sous-liste
# Out:
# [0, 3]

# %%
liste_B[0:5:2]  # début:fin:pas
# Out:
# [0, 2, 5]

# %%
liste_B[::-1]
# Out:
# [1, 6, 5, 4, 2, 3, 0]

# %%
# Fonctions de listes
List=[3,2,4,1]
List.sort()
print(List)
# Out:
# [1, 2, 3, 4]

# %%
List.append('hi')
print(List)
# Out:
# [1, 2, 3, 4, 'hi']

# %%
List.count(1)
# Out:
# 1

# %%
List.extend([7,8,9])
print(List)
# Out:
# [1, 2, 3, 4, 'hi', 7, 8, 9]

# %%
List.append([10,11,12])
print(List)
# Out:
# [1, 2, 3, 4, 'hi', 7, 8, 9, [10, 11, 12]]

# %% [markdown]
# #### t-uple
# Un tuple est similaire à une liste mais ne peut être modifié, il est défini par des parenthèses.

# %%
MyTuple=(0,3,2,'h')
MyTuple[1]
# Out:
# 3

# %%
MyTuple[1]=10 # TypeError: "tuple" object

# %% [markdown]
# #### Ensemble

# %%
Panier={'orange', 'poire', 'banane', 'kiwi'}
print(Panier)
# Out:
# {'kiwi', 'orange', 'poire', 'banane'}

# %%
'poire' in Panier

# %%
chaine1=set('abracadabra')
print(chaine1)
chaine2 = set('alacazam')
print(chaine1 & chaine2)
print(chaine1chaine2)

# %%
a = {x for x in 'abracadabra' if x not in 'abcy'}
print(a)
# Out:
# {'r', 'd'}

# %% [markdown]
# #### Dictionnaire
# Un dictionnaire est similaire à une liste mais chaque entrée est assignée par une clé / un nom, il est défini avec des accolades. Cet objet est utilisé pour la construction de l'index des colonnes (variables) du type *DataFrame* de la librairie `pandas`.

# %%
months = {'Jan':31 , 'Fev': 28, 'Mar':31}
months['Jan']
months
# Out:
# {'Jan': 31, 'Fev': 28, 'Mar': 31}

# %%
months.keys()
# Out:
# dict_keys(['Jan', 'Fev', 'Mar'])

# %%
months.values()
# Out:
# dict_values([31, 28, 31])

# %%
months.items()
# Out:
# dict_items([('Jan', 31), ('Fev', 28), ('Mar', 31)])

# %% [markdown]
# ## 3. Syntaxe de Python

# %% [markdown]
# ### 3.1 Structures de contrôle élémentaires
# Un bloc de commandes ou de codes est défini par *deux points suivis d'une indentation fixe*.  Cela oblige à l'écriture de codes faciles à lire mais à être très attentif sur la gestion des indentations car la fin d'indentation signifie la fin d'un bloc de commandes.

# %% [markdown]
# #### Structure conditionnelle

# %%
# si alors sinon
a=2
if a>0:
    b=0
    print(b)
else:
    b=-1
print(b)

# %% [markdown]
# #### Structure itérative

# %%
for i in range(4):
    print(i)

# %%
for i in range(1,8,2):
    print(i)

# %%
# Définition d'une fonction
def pythagorus(x,y):
    """ Calcule l'hypotenuse d'un triangle """
    r = pow(x**2+y**2,0.5)
    return x,y,r
pythagorus(3,4)

# %% [markdown]
# ### 3.2 Fonctions

# %%
# exemple d'appel
pythagorus(x=3,y=4)

# %%
# aide intégrée
help(pythagorus)

# %%
pythagorus.__doc__

# %%
# Valeurs des paramètres par défaut
def pythagorus(x=1,y=1):
    """ calcule l'hypoténuse d'un triangle """
    r = pow(x**2+y**2,0.5)
    return x,y,r
pythagorus()

# %% [markdown]
# # Exercice
#
# ## Exercices sur les Listes
#
# 1. Créer une liste de nombres
# Créez une liste contenant les nombres de 1 à 10. Affichez cette liste.
#
# 2. Ajouter et supprimer des éléments
# Ajoutez le nombre 11 à la fin de la liste.
# Supprimez le nombre 5 de la liste.
# Affichez la liste mise à jour.
# Accéder aux éléments d’une liste
# Affichez le premier et le dernier élément de la liste créée.
#
# 3. Utiliser les slices (tranches)
# Affichez les 3 premiers éléments de la liste et les 3 derniers éléments.
#
# 4. Liste de fruits
# Créez une liste contenant les noms de 5 fruits. Remplacez le troisième fruit par "mangue". Affichez la liste mise à jour.

# %% [markdown]
# ## Exercices sur les Ensembles
#
# 1. Créer un ensemble de nombres
# Créez un ensemble contenant les nombres 1, 2, 3, 4, et 5. Affichez cet ensemble.
#
# 2. Ajouter et supprimer des éléments
# Ajoutez le nombre 6 à l’ensemble.
# Supprimez le nombre 3 de l’ensemble.
# Affichez l'ensemble mis à jour.
# Vérifier la présence d'un élément
# Vérifiez si le nombre 2 est présent dans l’ensemble. Affichez True ou False.
#
# 3. Union et intersection de deux ensembles
# Créez deux ensembles, A avec les nombres 1, 2, 3, et B avec les nombres 3, 4, 5.
#
# 4. Calculez l’union de A et B (tous les éléments des deux ensembles).
# Calculez l’intersection de A et B (les éléments communs).
# Affichez les résultats.

# %% [markdown]
# ## Exercices sur les Tuples
#
# 1. Créer un tuple de couleurs
# Créez un tuple contenant les couleurs suivantes : "rouge", "vert", "bleu". Affichez ce tuple.
#
# 2. Accéder aux éléments d’un tuple
# Affichez la première couleur et la dernière couleur du tuple créé.
#
# 3. Immutabilité des tuples
# Essayez de changer le deuxième élément du tuple en "jaune". Que se passe-t-il ? Pourquoi ?
#
# 4. Utiliser des tuples pour retourner plusieurs valeurs
# Écrivez une fonction qui prend deux nombres et retourne à la fois leur somme et leur produit sous la forme d'un tuple. Appelez la fonction et affichez les valeurs de retour.

# %% [markdown]
# ## Exercices sur les Dictionnaires
#
# 1. Créer un dictionnaire de prix
# Créez un dictionnaire contenant les articles suivants avec leur prix :
#   "pomme" : 0.5, "banane" : 0.3, "orange" : 0.7. Affichez le dictionnaire.
#
# 2. Ajouter et mettre à jour des éléments
#
# Ajoutez un nouvel article, "poire", avec un prix de 0.8.
# Changez le prix de la "pomme" pour 0.6.
# Affichez le dictionnaire mis à jour.
# Accéder aux valeurs dans un dictionnaire
# Affichez le prix de la "banane" en accédant directement à l'élément correspondant dans le dictionnaire.
#
# 3. Boucler sur un dictionnaire
# Parcourez le dictionnaire et affichez chaque article avec son prix sous la forme : "Article: pomme, Prix: 0.5".
#
# 4. Vérifier la présence d'une clé
# Vérifiez si l'article "ananas" est présent dans le dictionnaire. Affichez True ou False.
